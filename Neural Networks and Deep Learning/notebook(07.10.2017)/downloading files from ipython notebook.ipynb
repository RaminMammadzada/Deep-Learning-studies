# %%
# !tar cvfz notebook.tar.gz *
# Out:
# Untitled.ipynb
# Week 2/
# Week 2/Python Basics with Numpy/
# Week 2/Python Basics with Numpy/.ipynb_checkpoints/
# Week 2/Python Basics with Numpy/.ipynb_checkpoints/Python Basics With Numpy v3-checkpoint.ipynb
# Week 2/Python Basics with Numpy/.ipynb_checkpoints/my tests-checkpoint.ipynb
# Week 2/Python Basics with Numpy/images/
# Week 2/Python Basics with Numpy/images/image2vector_kiank.png
# Week 2/Python Basics with Numpy/images/image2vector.png
# Week 2/Python Basics with Numpy/images/Sigmoid.png
# Week 2/Python Basics with Numpy/my tests.ipynb
# Week 2/Python Basics with Numpy/Python Basics With Numpy v3.ipynb
# Week 2/Logistic Regression as a Neural Network/
# Week 2/Logistic Regression as a Neural Network/.ipynb_checkpoints/
# Week 2/Logistic Regression as a Neural Network/.ipynb_checkpoints/Logistic Regression with a Neural Network mindset v4-checkpoint.ipynb
# Week 2/Logistic Regression as a Neural Network/images/
# ...

# %%
# !tar cvfz notebook.tar.gz *
# Out:
# Untitled.ipynb
# Week 2/
# Week 2/Python Basics with Numpy/
# Week 2/Python Basics with Numpy/.ipynb_checkpoints/
# Week 2/Python Basics with Numpy/.ipynb_checkpoints/Python Basics With Numpy v3-checkpoint.ipynb
# Week 2/Python Basics with Numpy/.ipynb_checkpoints/my tests-checkpoint.ipynb
# Week 2/Python Basics with Numpy/images/
# Week 2/Python Basics with Numpy/images/image2vector_kiank.png
# Week 2/Python Basics with Numpy/images/image2vector.png
# Week 2/Python Basics with Numpy/images/Sigmoid.png
# Week 2/Python Basics with Numpy/my tests.ipynb
# Week 2/Python Basics with Numpy/Python Basics With Numpy v3.ipynb
# Week 2/Logistic Regression as a Neural Network/
# Week 2/Logistic Regression as a Neural Network/.ipynb_checkpoints/
# Week 2/Logistic Regression as a Neural Network/.ipynb_checkpoints/Logistic Regression with a Neural Network mindset v4-checkpoint.ipynb
# Week 2/Logistic Regression as a Neural Network/images/
# ...
